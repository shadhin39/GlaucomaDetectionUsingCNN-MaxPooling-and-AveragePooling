# %% [markdown]
# <a href="https://colab.research.google.com/github/shadhin39/10MinuteSchoolDemo/blob/master/GlaucomaCNN_MaxPooling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
print(os.listdir(("/content/drive/My Drive/dataset")))
# Out:
# ['train', 'test', 'ConfusionMatrixDemo.png', 'ConfusionMatrixMaxPoolingMain.png', 'LossAveragePooling.png', 'AccuracyAveragePooling.png', 'GmodelCNNAveragePooling.h5', 'MSEAveragePooling.png', 'AUCAveragePooling.png', 'ConfusionMatrixAveragePooling.png', 'diagMax.svg', 'modelSimple.svg', 'CNNAveragePooling.png', 'MSEMaxPooling.png', 'AUCMaxPooling.png', 'ConfusionMatrixMaxPooling.png', 'CNNMaxPooling.png', 'LossMaxPooling.png', 'AccuracyMaxPooling.png', 'GmodelCNNMaxPooling.h5']

# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
# Initialising the CNN
classifier = Sequential()
# Step 1 - Convolution
classifier.add(Conv2D(32, (3, 3), input_shape = (256,256, 3), activation = 'relu'))
# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))
# Adding a second convolutional layer
classifier.add(Conv2D(32, (3, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))
# Step 3 - Flattening
classifier.add(Flatten())
# Step 4 - Full connection
classifier.add(Dense(units = 128, activation = 'relu'))
classifier.add(Dense(units = 1, activation = 'sigmoid'))
# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255,
shear_range = 0.2,
zoom_range = 0.2,
horizontal_flip = True)
# print(train_datagen)
test_datagen = ImageDataGenerator(rescale = 1./255)
training_set = train_datagen.flow_from_directory('/content/drive/My Drive/dataset/train',
target_size = (256,256),
batch_size = 32,
class_mode = 'binary')
# print(test_datagen)
test_set = test_datagen.flow_from_directory('/content/drive/My Drive/dataset/test',
target_size = (256,256),
batch_size = 32,
class_mode = 'binary')
# Out:
# Found 455 images belonging to 2 classes.
# Found 64 images belonging to 2 classes.

# %%
history = classifier.fit(training_set, validation_data = test_set,batch_size=32,epochs=30, verbose=2)
# Out:
# Epoch 1/30
# 15/15 - 41s - loss: 0.1523 - accuracy: 0.9429 - val_loss: 0.1847 - val_accuracy: 0.9531
# Epoch 2/30
# 15/15 - 40s - loss: 0.2353 - accuracy: 0.9209 - val_loss: 0.1511 - val_accuracy: 0.9688
# Epoch 3/30
# 15/15 - 40s - loss: 0.1911 - accuracy: 0.9275 - val_loss: 0.1559 - val_accuracy: 0.9375
# Epoch 4/30
# 15/15 - 40s - loss: 0.1867 - accuracy: 0.9341 - val_loss: 0.1296 - val_accuracy: 0.9375
# Epoch 5/30
# 15/15 - 40s - loss: 0.1909 - accuracy: 0.9209 - val_loss: 0.1864 - val_accuracy: 0.9531
# Epoch 6/30
# 15/15 - 40s - loss: 0.1480 - accuracy: 0.9495 - val_loss: 0.1915 - val_accuracy: 0.9219
# Epoch 7/30
# 15/15 - 40s - loss: 0.1757 - accuracy: 0.9055 - val_loss: 0.1307 - val_accuracy: 0.9531
# Epoch 8/30
# 15/15 - 40s - loss: 0.1998 - accuracy: 0.9055 - val_loss: 0.1793 - val_accuracy: 0.9062
# Epoch 9/30
# 15/15 - 40s - loss: 0.1852 - accuracy: 0.9341 - val_loss: 0.1466 - val_accuracy: 0.9219
# Epoch 10/30
# 15/15 - 40s - loss: 0.1514 - accuracy: 0.9516 - val_loss: 0.1600 - val_accuracy: 0.9062
# Epoch 11/30
# 15/15 - 40s - loss: 0.1638 - accuracy: 0.9275 - val_loss: 0.1098 - val_accuracy: 0.9688
# Epoch 12/30
# 15/15 - 41s - loss: 0.1610 - accuracy: 0.9407 - val_loss: 0.1055 - val_accuracy: 0.9531
# Epoch 13/30
# 15/15 - 40s - loss: 0.1602 - accuracy: 0.9516 - val_loss: 0.1534 - val_accuracy: 0.9375
# Epoch 14/30
# 15/15 - 40s - loss: 0.1624 - accuracy: 0.9363 - val_loss: 0.1409 - val_accuracy: 0.9375
# Epoch 15/30
# 15/15 - 40s - loss: 0.2039 - accuracy: 0.9143 - val_loss: 0.1065 - val_accuracy: 0.9688
# Epoch 16/30
# 15/15 - 40s - loss: 0.1785 - accuracy: 0.9275 - val_loss: 0.1677 - val_accuracy: 0.9531
# Epoch 17/30
# 15/15 - 41s - loss: 0.1998 - accuracy: 0.9187 - val_loss: 0.2373 - val_accuracy: 0.8906
# Epoch 18/30
# 15/15 - 41s - loss: 0.2086 - accuracy: 0.9187 - val_loss: 0.1319 - val_accuracy: 0.9688
# Epoch 19/30
# 15/15 - 40s - loss: 0.1496 - accuracy: 0.9516 - val_loss: 0.1297 - val_accuracy: 0.9375
# Epoch 20/30
# 15/15 - 40s - loss: 0.1473 - accuracy: 0.9495 - val_loss: 0.1029 - val_accuracy: 0.9688
# Epoch 21/30
# 15/15 - 40s - loss: 0.1249 - accuracy: 0.9495 - val_loss: 0.0944 - val_accuracy: 0.9688
# Epoch 22/30
# 15/15 - 40s - loss: 0.1462 - accuracy: 0.9473 - val_loss: 0.1086 - val_accuracy: 0.9531
# Epoch 23/30
# 15/15 - 41s - loss: 0.1138 - accuracy: 0.9604 - val_loss: 0.0820 - val_accuracy: 0.9688
# Epoch 24/30
# 15/15 - 41s - loss: 0.1334 - accuracy: 0.9495 - val_loss: 0.0783 - val_accuracy: 0.9844
# Epoch 25/30
# 15/15 - 41s - loss: 0.1252 - accuracy: 0.9538 - val_loss: 0.1333 - val_accuracy: 0.9062
# Epoch 26/30
# 15/15 - 40s - loss: 0.1897 - accuracy: 0.9209 - val_loss: 0.3071 - val_accuracy: 0.8750
# Epoch 27/30
# 15/15 - 40s - loss: 0.1846 - accuracy: 0.9341 - val_loss: 0.1836 - val_accuracy: 0.8906
# Epoch 28/30
# 15/15 - 40s - loss: 0.1670 - accuracy: 0.9319 - val_loss: 0.1263 - val_accuracy: 0.9375
# Epoch 29/30
# 15/15 - 40s - loss: 0.1295 - accuracy: 0.9516 - val_loss: 0.1491 - val_accuracy: 0.9375
# Epoch 30/30
# 15/15 - 40s - loss: 0.1096 - accuracy: 0.9604 - val_loss: 0.1040 - val_accuracy: 0.9531

# %%
# evaluate the model
_, train_acc = classifier.evaluate(training_set, verbose=0)
_, test_acc = classifier.evaluate(test_set, verbose=0)
print(" Train_accuracy: ", train_acc)
print(" Test_accuracy: ", test_acc)
# Out:
#  Train_accuracy:  0.9516483545303345
#  Test_accuracy:  0.953125

# %%
### Performance evaluation
#########################
score = classifier.evaluate(test_set)
print(" Total: ", len(test_set.filenames))
print("Loss: ", score[0], "Accuracy: ", score[1])
# Out:
# 2/2 [==============================] - 2s 573ms/step - loss: 0.1040 - accuracy: 0.9531
#  Total:  64
# Loss:  0.10403507202863693 Accuracy:  0.953125

# %%
# plot loss during training
import matplotlib.pyplot as pyplot
pyplot.subplot(211)
pyplot.title('Model Loss')
pyplot.ylabel('Loss')
pyplot.xlabel('Epoch')
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.savefig('/content/drive/My Drive/dataset/LossMaxPooling.png')
pyplot.legend()
pyplot.show()

# %%
# plot accuracy during training
pyplot.subplot(212)
pyplot.title('Model Accuracy')
pyplot.ylabel('Accuracy')
pyplot.xlabel('Epoch')
pyplot.plot(history.history['accuracy'], label='train')
pyplot.plot(history.history['val_accuracy'], label='test')
pyplot.savefig('/content/drive/My Drive/dataset/AccuracyMaxPooling.png')
pyplot.legend()
pyplot.show()

# %%
classifier.save('/content/drive/My Drive/dataset/GmodelCNNMaxPooling.h5')

# %%
import os
from keras.models import load_model
from PIL import Image
from keras.preprocessing import image
import numpy as np
import cv2
target_size = (256,256)
model=load_model('/content/drive/My Drive/dataset/GmodelCNNMaxPooling.h5')
print("model loaded")
# Out:
# model loaded

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('/content/drive/My Drive/dataset/test/class1/Im263.jpg', target_size = (256,256))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
 print("Glaucoma")
else:
 print("Not Glaucoma")
# Out:
# Glaucoma

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('/content/drive/My Drive/dataset/test/class0/Im181.jpg', target_size = (256,256))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
 print("Glaucoma")
else:
 print("Not Glaucoma")
# Out:
# Not Glaucoma

# %%
from numpy import array
from keras.models import Sequential
from keras.layers import Dense
from matplotlib import pyplot
classifier.compile(
    optimizer='adam',
    loss='mean_squared_error',
    metrics=[
        'MeanSquaredError',
        'AUC',
    ]
)

history = classifier.fit(training_set, validation_data = test_set, epochs=30, batch_size=32, verbose=2)
# Out:
# Epoch 1/30
# 15/15 - 42s - loss: 0.0615 - mean_squared_error: 0.0615 - auc: 0.9769 - val_loss: 0.0315 - val_mean_squared_error: 0.0315 - val_auc: 0.9971
# Epoch 2/30
# 15/15 - 41s - loss: 0.0453 - mean_squared_error: 0.0453 - auc: 0.9813 - val_loss: 0.0206 - val_mean_squared_error: 0.0206 - val_auc: 1.0000
# Epoch 3/30
# 15/15 - 41s - loss: 0.0334 - mean_squared_error: 0.0334 - auc: 0.9912 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - val_auc: 0.9971
# Epoch 4/30
# 15/15 - 41s - loss: 0.0341 - mean_squared_error: 0.0341 - auc: 0.9917 - val_loss: 0.0141 - val_mean_squared_error: 0.0141 - val_auc: 1.0000
# Epoch 5/30
# 15/15 - 41s - loss: 0.0348 - mean_squared_error: 0.0348 - auc: 0.9908 - val_loss: 0.0184 - val_mean_squared_error: 0.0184 - val_auc: 0.9990
# Epoch 6/30
# 15/15 - 41s - loss: 0.0411 - mean_squared_error: 0.0411 - auc: 0.9891 - val_loss: 0.0374 - val_mean_squared_error: 0.0374 - val_auc: 0.9951
# Epoch 7/30
# 15/15 - 41s - loss: 0.0567 - mean_squared_error: 0.0567 - auc: 0.9732 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - val_auc: 0.9922
# Epoch 8/30
# 15/15 - 41s - loss: 0.0337 - mean_squared_error: 0.0337 - auc: 0.9881 - val_loss: 0.0172 - val_mean_squared_error: 0.0172 - val_auc: 0.9990
# Epoch 9/30
# 15/15 - 41s - loss: 0.0374 - mean_squared_error: 0.0374 - auc: 0.9896 - val_loss: 0.0171 - val_mean_squared_error: 0.0171 - val_auc: 1.0000
# Epoch 10/30
# 15/15 - 41s - loss: 0.0313 - mean_squared_error: 0.0313 - auc: 0.9925 - val_loss: 0.0198 - val_mean_squared_error: 0.0198 - val_auc: 0.9980
# Epoch 11/30
# 15/15 - 41s - loss: 0.0348 - mean_squared_error: 0.0348 - auc: 0.9882 - val_loss: 0.0175 - val_mean_squared_error: 0.0175 - val_auc: 0.9985
# Epoch 12/30
# 15/15 - 41s - loss: 0.0347 - mean_squared_error: 0.0347 - auc: 0.9911 - val_loss: 0.0115 - val_mean_squared_error: 0.0115 - val_auc: 1.0000
# Epoch 13/30
# 15/15 - 41s - loss: 0.0354 - mean_squared_error: 0.0354 - auc: 0.9912 - val_loss: 0.0291 - val_mean_squared_error: 0.0291 - val_auc: 1.0000
# Epoch 14/30
# 15/15 - 41s - loss: 0.0473 - mean_squared_error: 0.0473 - auc: 0.9857 - val_loss: 0.0483 - val_mean_squared_error: 0.0483 - val_auc: 0.9873
# Epoch 15/30
# 15/15 - 41s - loss: 0.0502 - mean_squared_error: 0.0502 - auc: 0.9781 - val_loss: 0.0180 - val_mean_squared_error: 0.0180 - val_auc: 1.0000
# Epoch 16/30
# 15/15 - 41s - loss: 0.0374 - mean_squared_error: 0.0374 - auc: 0.9877 - val_loss: 0.0426 - val_mean_squared_error: 0.0426 - val_auc: 0.9956
# Epoch 17/30
# 15/15 - 41s - loss: 0.0358 - mean_squared_error: 0.0358 - auc: 0.9905 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - val_auc: 0.9990
# Epoch 18/30
# 15/15 - 41s - loss: 0.0256 - mean_squared_error: 0.0256 - auc: 0.9946 - val_loss: 0.0039 - val_mean_squared_error: 0.0039 - val_auc: 1.0000
# Epoch 19/30
# 15/15 - 41s - loss: 0.0254 - mean_squared_error: 0.0254 - auc: 0.9941 - val_loss: 0.0047 - val_mean_squared_error: 0.0047 - val_auc: 1.0000
# Epoch 20/30
# 15/15 - 41s - loss: 0.0257 - mean_squared_error: 0.0257 - auc: 0.9945 - val_loss: 0.0232 - val_mean_squared_error: 0.0232 - val_auc: 1.0000
# Epoch 21/30
# 15/15 - 41s - loss: 0.0444 - mean_squared_error: 0.0444 - auc: 0.9861 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - val_auc: 1.0000
# Epoch 22/30
# 15/15 - 40s - loss: 0.0382 - mean_squared_error: 0.0382 - auc: 0.9853 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - val_auc: 1.0000
# Epoch 23/30
# 15/15 - 40s - loss: 0.0175 - mean_squared_error: 0.0175 - auc: 0.9985 - val_loss: 0.0055 - val_mean_squared_error: 0.0055 - val_auc: 1.0000
# Epoch 24/30
# 15/15 - 40s - loss: 0.0299 - mean_squared_error: 0.0299 - auc: 0.9933 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - val_auc: 1.0000
# Epoch 25/30
# 15/15 - 40s - loss: 0.0233 - mean_squared_error: 0.0233 - auc: 0.9936 - val_loss: 0.0042 - val_mean_squared_error: 0.0042 - val_auc: 1.0000
# Epoch 26/30
# 15/15 - 40s - loss: 0.0241 - mean_squared_error: 0.0241 - auc: 0.9965 - val_loss: 0.0194 - val_mean_squared_error: 0.0194 - val_auc: 1.0000
# Epoch 27/30
# 15/15 - 40s - loss: 0.0266 - mean_squared_error: 0.0266 - auc: 0.9954 - val_loss: 0.0228 - val_mean_squared_error: 0.0228 - val_auc: 1.0000
# Epoch 28/30
# 15/15 - 40s - loss: 0.0355 - mean_squared_error: 0.0355 - auc: 0.9896 - val_loss: 0.0115 - val_mean_squared_error: 0.0115 - val_auc: 1.0000
# Epoch 29/30
# 15/15 - 40s - loss: 0.0412 - mean_squared_error: 0.0412 - auc: 0.9865 - val_loss: 0.0155 - val_mean_squared_error: 0.0155 - val_auc: 1.0000
# Epoch 30/30
# 15/15 - 40s - loss: 0.0366 - mean_squared_error: 0.0366 - auc: 0.9882 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - val_auc: 1.0000

# %%
#mean-square error
pyplot.subplot(212)
pyplot.title('Model Mean-square Error')
pyplot.ylabel('Mean-square Error')
pyplot.xlabel('Epoch')
pyplot.plot(history.history['mean_squared_error'])
pyplot.savefig('/content/drive/My Drive/dataset/MSEMaxPooling.png')
pyplot.legend()
pyplot.show()
# Out:
# No handles with labels found to put in legend.

# %%
#auc value
pyplot.subplot(212)
pyplot.title('Model AUC')
pyplot.ylabel('AUC')
pyplot.xlabel('Epoch')
pyplot.plot(history.history['auc'])
pyplot.savefig('/content/drive/My Drive/dataset/AUCMaxPooling.png')
pyplot.legend()
pyplot.show()
# Out:
# No handles with labels found to put in legend.

# %%
#confusion matrix values
classifier.compile(optimizer='sgd',
              loss='mse',
              metrics=['TruePositives','TrueNegatives','FalsePositives','FalseNegatives'])
history = classifier.fit(training_set, validation_data = test_set, epochs=10, batch_size=32, verbose=2)
# Out:
# Epoch 1/10
# 15/15 - 42s - loss: 0.0441 - true_positives: 188.0000 - true_negatives: 242.0000 - false_positives: 13.0000 - false_negatives: 12.0000 - val_loss: 0.0218 - val_true_positives: 31.0000 - val_true_negatives: 31.0000 - val_false_positives: 1.0000 - val_false_negatives: 1.0000
# Epoch 2/10
# 15/15 - 40s - loss: 0.0498 - true_positives: 185.0000 - true_negatives: 237.0000 - false_positives: 18.0000 - false_negatives: 15.0000 - val_loss: 0.0172 - val_true_positives: 31.0000 - val_true_negatives: 32.0000 - val_false_positives: 0.0000e+00 - val_false_negatives: 1.0000
# Epoch 3/10
# 15/15 - 40s - loss: 0.0363 - true_positives: 190.0000 - true_negatives: 244.0000 - false_positives: 11.0000 - false_negatives: 10.0000 - val_loss: 0.0216 - val_true_positives: 31.0000 - val_true_negatives: 31.0000 - val_false_positives: 1.0000 - val_false_negatives: 1.0000
# Epoch 4/10
# 15/15 - 41s - loss: 0.0347 - true_positives: 189.0000 - true_negatives: 247.0000 - false_positives: 8.0000 - false_negatives: 11.0000 - val_loss: 0.0223 - val_true_positives: 32.0000 - val_true_negatives: 30.0000 - val_false_positives: 2.0000 - val_false_negatives: 0.0000e+00
# Epoch 5/10
# 15/15 - 41s - loss: 0.0225 - true_positives: 190.0000 - true_negatives: 250.0000 - false_positives: 5.0000 - false_negatives: 10.0000 - val_loss: 0.0176 - val_true_positives: 32.0000 - val_true_negatives: 32.0000 - val_false_positives: 0.0000e+00 - val_false_negatives: 0.0000e+00
# Epoch 6/10
# 15/15 - 40s - loss: 0.0301 - true_positives: 191.0000 - true_negatives: 243.0000 - false_positives: 12.0000 - false_negatives: 9.0000 - val_loss: 0.0299 - val_true_positives: 31.0000 - val_true_negatives: 31.0000 - val_false_positives: 1.0000 - val_false_negatives: 1.0000
# Epoch 7/10
# 15/15 - 40s - loss: 0.0288 - true_positives: 194.0000 - true_negatives: 246.0000 - false_positives: 9.0000 - false_negatives: 6.0000 - val_loss: 0.0195 - val_true_positives: 32.0000 - val_true_negatives: 32.0000 - val_false_positives: 0.0000e+00 - val_false_negatives: 0.0000e+00
# Epoch 8/10
# 15/15 - 41s - loss: 0.0292 - true_positives: 190.0000 - true_negatives: 248.0000 - false_positives: 7.0000 - false_negatives: 10.0000 - val_loss: 0.0295 - val_true_positives: 31.0000 - val_true_negatives: 30.0000 - val_false_positives: 2.0000 - val_false_negatives: 1.0000
# Epoch 9/10
# 15/15 - 40s - loss: 0.0319 - true_positives: 190.0000 - true_negatives: 245.0000 - false_positives: 10.0000 - false_negatives: 10.0000 - val_loss: 0.0310 - val_true_positives: 31.0000 - val_true_negatives: 30.0000 - val_false_positives: 2.0000 - val_false_negatives: 1.0000
# Epoch 10/10
# 15/15 - 40s - loss: 0.0362 - true_positives: 188.0000 - true_negatives: 243.0000 - false_positives: 12.0000 - false_negatives: 12.0000 - val_loss: 0.0300 - val_true_positives: 32.0000 - val_true_negatives: 29.0000 - val_false_positives: 3.0000 - val_false_negatives: 0.0000e+00

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

array = [[29,3],
         [0,32]]

df_cm = pd.DataFrame(array, range(2), range(2))

sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 12}) # font size
pyplot.title('Confusion Matrix')
pyplot.ylabel('Actual Class')
pyplot.xlabel('Predicted Class')
pyplot.savefig('/content/drive/My Drive/dataset/ConfusionMatrixMaxPooling.png')
pyplot.show()

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 254, 254, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 127, 127, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 125, 125, 32)      9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 62, 62, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 123008)            0
# _________________________________________________________________
# dense (Dense)                (None, 128)               15745152
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 15,755,425
# Trainable params: 15,755,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model as plot
plot(classifier, to_file='/content/drive/My Drive/dataset/CNNMaxPooling.png')
